# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# __Objectives:__
# - List popular languages for Data Science
# - List popular libraries for Data Science
# - List popular open source development environment for Data Science
# - Demonstrate Python with simple arithmetic expressions

# %% [markdown]
# Some of the popular __languages__ that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. R

# %% [markdown]
# Some of the commonly used __Python libraries__ used by Data Scientists include:
# 1. Numpy
# 2. SciPy
# 3. Pandas
# 4. Matplotlib
# 5. Seaborn
# 6. Scikit-learn
# 7. Keras
# 8. TensorFlow
# 9. PyTorch
#
# Some of the commonly used __R libraries__ used by Data Scientists include:
# 1. dplyr
# 2. ggplot2
# 3. caret
# 4. keras

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter           |
# |Spyder            |
# |RStudio           |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.
nb_minutes = 200
nb_minutes_per_hour = 60
nb_minutes/nb_minutes_per_hour
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# JS
